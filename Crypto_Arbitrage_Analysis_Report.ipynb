# %% [markdown]
# # Crypto Arbitrage Analysis Report
#
# Below are screenshots of line graphs from the crypto_arbitrage program for different time periods, 'zooming in' to narrower windows of time as they progress. We start with a 3-year period, then move on to two specific months, and finally, three specific days which also have screenshots of their summary statistics and box plots.

# %% [markdown]
# Three year period:
# ![Screen Shot 2021-01-24 at 10.24.48 PM.png](attachment:aa67c336-ab3f-4f58-914a-21f74f10e433.png)
#
# One month periods:
# ![Screen Shot 2021-01-24 at 10.25.13 PM.png](attachment:03916d9d-dead-4096-a828-f667bbc8a87f.png)
# ![Screen Shot 2021-01-24 at 10.25.36 PM.png](attachment:385b11db-10b2-4394-90cf-7d0476f72909.png)

# %% [markdown]
# **Question** Based on the visualizations of the different time periods, has the degree of spread changed as time progressed?
#
# **Answer** Based on the graphs for two seperate time periods, it appears that the degree of spread has lessened as time has progressed. It is possible that the months we have chosen to look as just happen to make it appear that way. However, this is unlikely because it would make logical sense for the dergee of spread to minimize due to arbitrage trading causing the markets to equalize over time.

# %% [markdown]
# One day periods:
# ![Screen Shot 2021-01-24 at 10.08.44 PM.png](attachment:fa22e525-b1d8-4f50-b225-f8d8bc6bb527.png)
# ![Screen Shot 2021-01-24 at 10.10.19 PM.png](attachment:2c3331b3-75c7-4d6d-93ac-2001d4e15c9f.png)
# ![Screen Shot 2021-01-24 at 10.10.37 PM.png](attachment:e14dcfe5-a0d6-450a-8c08-9201167f9386.png)
#
# **The sum of the potential profit on this day was 142.39 USD **
#
#
# ![Screen Shot 2021-01-24 at 10.11.05 PM.png](attachment:5d4976a5-46ab-4197-b3ea-e8dac0aeb8d2.png)
# ![Screen Shot 2021-01-24 at 10.11.23 PM.png](attachment:214deca8-fed0-46ab-bf5c-6909999bd956.png)
# ![Screen Shot 2021-01-24 at 10.11.35 PM.png](attachment:f07d57db-987c-45ee-a369-08985adcc018.png)
#
# **The sum of the potential profit on this day was 20092.30 USD **
#
#
# ![Screen Shot 2021-01-24 at 10.12.05 PM.png](attachment:6873d1e1-3717-4c8d-8baa-2a012f264a9c.png)
# ![Screen Shot 2021-01-24 at 10.12.28 PM.png](attachment:bb103f56-8af5-406e-bab1-2192241a4132.png)
# ![Screen Shot 2021-01-24 at 10.12.43 PM.png](attachment:79936f26-3213-4e88-998a-38dcb5a72658.png)
#
# **The sum of the potential profit on this day was 0.00 USD **

# %% [markdown]
# **Question:** After reviewing the profit information across each date from the different time periods, can you identify any patterns or trends?
#
# **Answer:** Arbitrage profits are extremely hard to come by as the market for Bitcoin matures across time. As Bitcoin grows in popularity, the prices across the two exhanges trade more in line with one another. That makes it very difficult find a point where the price difference exceeds the minimum profit threshold of 1%.
